# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')

# %%
df.head(5)
# Out:
#         fever  Body pain  Age  Runny nose  Diff Breathing  Infection prob
# 0   98.016286          1    1           1               1               0
# 1  100.497296          1   42           0              -1               0
# 2  101.289146          0   28           0               0               0
# 3   98.740278          1   15           1              -1               1
# 4  101.453507          1   88           1              -1               1

# %%
df.tail(5)
# Out:
#            fever  Body pain  Age  Runny nose  Diff Breathing  Infection prob
# 3921   98.016829          1   45           1               1               1
# 3922   98.030849          1   28           1              -1               1
# 3923   99.091965          1   25           1               1               0
# 3924   99.544388          1   36           1               1               1
# 3925  101.248003          1   72           1               0               0

# %%
df.ifo()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10768\1126135030.py in ?()
# ----> 1 df.ifo()
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'ifo'

# %%
df['Diff Breathing'].value_counts()#it means how many people from total have same type of breathing levels
# Out:
# Diff Breathing
#  0    1328
#  1    1326
# -1    1272
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#              fever    Body pain          Age   Runny nose  Diff Breathing  \
# count  3926.000000  3926.000000  3926.000000  3926.000000     3926.000000
# mean    100.009843     0.491085    49.933265     0.499745        0.013754
# std       1.161121     0.499984    28.740298     0.500064        0.813463
# min      98.001445     0.000000     1.000000     0.000000       -1.000000
# 25%      98.970799     0.000000    25.000000     0.000000       -1.000000
# 50%     100.057178     0.000000    50.000000     0.000000        0.000000
# 75%     101.015086     1.000000    74.000000     1.000000        1.000000
# max     101.999008     1.000000   100.000000     1.000000        1.000000
#
#        Infection prob
# count     3926.000000
# mean         0.491849
# std          0.499997
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000

# %%
# TRAIN TEST SPILLITING

# %%
import numpy as np

# %%
def data_split(data,ratio):
    np.random.seed(42)
    shuffled = np.random.permutation(len(data))
    test_set_size = int(len(data)*ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    return data.iloc[train_indices],data.iloc[test_indices]

# %%
np.random.permutation(7) # it prints the random numbers between the given limit
# Out:
# array([2, 3, 5, 0, 1, 4, 6])

# %%
train , test = data_split(df, 0.2)

# %%
train
# Out:
#            fever  Body pain  Age  Runny nose  Diff Breathing  Infection prob
# 871   101.918189          0   36           0               1               0
# 1071   98.111349          1    8           1               0               0
# 3687  100.322737          1   20           1              -1               1
# 3398  100.820554          1   10           0               0               0
# 1138  100.811982          0   19           1              -1               1
# ...          ...        ...  ...         ...             ...             ...
# 1130   99.037635          1   73           1               1               0
# 1294   98.976526          0    4           0              -1               1
# 860   100.157485          1   51           0              -1               0
# 3507  100.797483          1   80           1              -1               0
# 3174   98.604242          0   44           1              -1               0
#
# [3141 rows x 6 columns]

# %%
test
# Out:
#            fever  Body pain  Age  Runny nose  Diff Breathing  Infection prob
# 3476  101.103647          0   40           1               0               0
# 463   101.020090          1   14           0               1               0
# 3857   98.312113          1   67           0               1               0
# 3173  101.679404          0   70           0               0               1
# 2092   98.545499          0   14           0               0               0
# ...          ...        ...  ...         ...             ...             ...
# 3608   98.126631          1   84           1              -1               0
# 3106   98.536093          0   14           0               0               0
# 2935   98.421143          1   25           1               0               1
# 1910  101.710997          0   46           0               0               0
# 1770   98.223186          0   20           0               1               1
#
# [785 rows x 6 columns]

# %%
x_train=train[['fever','Body pain','Age','Runny nose','Diff Breathing']].to_numpy()
x_teast=test[['fever','Body pain','Age','Runny nose','Diff Breathing']].to_numpy()

# %%
y_train=train[['Infection prob']].to_numpy().reshape(3141)#reshape is used to change the sahpe like row into column shape
y_test=test[['Infection prob']].to_numpy().reshape(785)

# %%
y_train
# Out:
# array([0, 0, 1, ..., 0, 0, 0], dtype=int64)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
inputfeatures = [100,1,22,1,1]
inf_prob=clf.predict_proba([inputfeatures])[0][1]# predict only preddict yes or no but probability tells abut the percentage

# %%
inf_prob
# Out:
# 0.4787008410152565
